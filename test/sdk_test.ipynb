# %%
# import sys
# import os

# current_dir = os.getcwd()
# edge_sdk_dir = os.path.join(current_dir, "..", "edge_sdk")
# sys.path.append(edge_sdk_dir)

# %%
from edge_sdk.edge_app_emulator import EdgeAppEmulator

# %%
emulator = EdgeAppEmulator('/home/gyulim.gu/projects/edge_sdk/test/emulator_config.yaml')

try :
    emulator.start()
    if emulator.deploy_model():
        if emulator.inference_file("/home/gyulim.gu/projects/edge_sdk/test/20240903-134104.945.csv"):
            emulator.upload_inference_result()
finally:
    emulator.stop()
# Out:
# 2025-01-02 11:18:20.091 | INFO     | edge_sdk.edge_client:__init__:30 - wss://edgecond.try-mellerikat.com/app/api/v1/socket/edge-sdk-emulator-gyulim.gu2
# 2025-01-02 11:18:20.517 | INFO     | edge_sdk.edge_client:authenticate:129 - JWT Token:
# 2025-01-02 11:18:20.670 | INFO     | edge_sdk.edge_client:read_info:147 - GET Success!
# 2025-01-02 11:18:20.672 | INFO     | edge_sdk.edge_client:read_info:148 - Edge Details:
# 2025-01-02 11:18:20.675 | INFO     | edge_sdk.edge_client:read_info:149 - Edge ID: edge-sdk-emulator-gyulim.gu2
# 2025-01-02 11:18:20.676 | INFO     | edge_sdk.edge_client:read_info:150 - Edge Name: Edge SDK Emulator
# 2025-01-02 11:18:20.678 | INFO     | edge_sdk.edge_client:read_info:151 - Edge Desc:
# 2025-01-02 11:18:20.681 | INFO     | edge_sdk.edge_client:read_info:152 - Edge Location: Gyulim Laptop
# 2025-01-02 11:18:20.682 | INFO     | edge_sdk.edge_client:read_info:153 - Edge State: registered
# 2025-01-02 11:18:20.684 | INFO     | edge_sdk.edge_client:read_info:154 - Edge Status: disconnected
# 2025-01-02 11:18:20.686 | INFO     | edge_sdk.edge_client:read_info:155 - Created At: 2024-12-31T07:37:56
# 2025-01-02 11:18:20.687 | INFO     | edge_sdk.edge_client:read_info:156 - Creator: gyulim.gu
# 2025-01-02 11:18:20.689 | INFO     | edge_sdk.edge_client:read_info:162 -
# Deployed Info: {'model_seq': 58, 'model_version': '2.1', 'stream_name': '[Try] Bolt Fastening Anomaly Detection', 'inference_docker': '339713051385.dkr.ecr.ap-northeast-2.amazonaws.com/ecr-repo-an2-iac-prod/poc/ai-solutions/bolt-fastening-anomaly-detection/inference/bolt-fastening-anomaly-detection:v2', 'deploy_datetime': '2024-12-31T07:43:15'}
# 2025-01-02 11:18:20.690 | INFO     | edge_sdk.edge_client:read_info:163 - Deploy Model: None
# 2025-01-02 11:18:20.692 | INFO     | edge_sdk.edge_client:read_info:164 - Update Edge Docker: None
# 2025-01-02 11:18:20.816 | WARNING  | edge_sdk.edge_client:receive:41 - receive close
# 2025-01-02 11:18:20.845 | INFO     | edge_sdk.edge_app_emulator:deploy_model:82 - Use exist model
# 2025-01-02 11:18:20.846 | INFO     | edge_sdk.edge_app_emulator:inference_file:166 - inference_file : /home/gyulim.gu/projects/edge_sdk/test/20240903-134104.945.csv
# 2025-01-02 11:18:20.909 | INFO     | edge_sdk.edge_app_emulator:run_alo_inference:217 - run_alo_inference
# 2025-01-02 11:18:21.338 | ERROR    | edge_sdk.edge_app_emulator:run_alo_inference:240 - run alo fail
# 2025-01-02 11:18:21.341 | INFO     | edge_sdk.edge_client:disconnect:70 - socket close
